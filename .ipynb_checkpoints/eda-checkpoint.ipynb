# %%
import pandas as pd

usage = pd.read_csv(f"dataset/usage_monthly.csv")
tickets = pd.read_csv(f"dataset/support_tickets_monthly.csv")
renewals = pd.read_csv(f"dataset/renewals.csv")
companies = pd.read_csv(f"dataset/companies.csv")
contracts = pd.read_csv(f"dataset/contracts.csv")

print("Monthly Usage\n",usage.head())
print("\n\nMonthly Support Tickets\n",tickets.head())
print("\n\nRenewals\n",renewals.head())
print("\n\nCompanies\n",companies.head())
print("\n\nContracts\n",contracts.head())
# Out:
# Monthly Usage
#     contract_id  month_index  logins_total  active_users  leads_created  \
# 0            0            0            72             8             32
# 1            0            1            40             8              0
# 2            0            2            72             8              8
# 3            0            3            40             8             16
# 4            0            4            72             8              8
#
#    opportunities_created  reports_generated  feature_adoption_score
# 0                     15                 16                0.390718
# 1                      0                 16                0.390718
# 2                      2                 16                0.390718
# 3                     10                 24                0.390718
# 4                      2                  8                0.390718
#
#
# Monthly Support Tickets
#     contract_id  month_index  ticket_count  avg_resolution_hours  csat_score  \
# 0            0            0             3             10.049976    2.954071
# 1            0            1             1             14.235582         NaN
# 2            0            2             2              9.084398         NaN
# 3            0            3             0             13.221284         NaN
# 4            0            4             1             14.947153    3.594038
#
#    escalation_count
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# 4                 0
#
#
# Renewals
#     contract_id  seats_start  logins_total  active_users  renewed  seat_change
# 0            0           23     59.200000           8.0        1            2
# 1            1           15     69.333333           8.0        1            2
# 2            2           15     25.615385           3.0        1            6
# 3            3           46    109.571429          13.0        0            5
# 4            4           18     40.571429           4.0        1            0
#
#
# Companies
#     company_id  company_size       industry region  growth_rate  \
# 0           0            62           tech     EU     0.050758
# 1           1           143         retail   APAC     0.128424
# 2           2           151  manufacturing   APAC     0.141777
# 3           3           238         retail    NaN     0.067953
# 4           4            37     healthcare    NaN     0.198458
#
#    annual_revenue  crm_maturity_score
# 0    6.463845e+06            0.270580
# 1    1.245357e+07            0.510263
# 2    1.680633e+07            0.432901
# 3    8.462937e+06            0.340177
# 4    5.445396e+06            0.231505
#
#
# Contracts
#     contract_id  company_id  company_size       industry region  growth_rate  \
# 0            0         598           226           tech     EU     0.059017
# 1            1          39            74         retail    NaN     0.123574
# 2            2         160           150  manufacturing    NaN     0.055199
# 3            3         702           288         retail    NaN     0.131426
# 4            4         536           184         retail    NaN     0.083454
#
#    annual_revenue  sales_process_maturity  crm_maturity_score  seats_start  \
# 0    1.782664e+07                1.200079            0.627441           23
# 1    2.911474e+06               -1.769076            0.278178           15
# 2    1.409863e+07               -1.111458            0.611711           15
# 3    3.436947e+07                2.012270            0.695971           46
# 4    2.407745e+07                0.975817            0.546493           18
#
#       plan_tier  price_per_seat  discount_pct  contract_value  duration_months
# 0    Enterprise             120      0.264037     2031.257870               10
# 1  Professional              60      0.089815      819.166421               12
# 2  Professional              60      0.279983      648.015483               13
# 3         Basic              25      0.033091     1111.945865                7
# 4  Professional              60      0.089121      983.748806                7

# %%
# Aggregate usage
usage_agg = usage.groupby("contract_id").agg({
    "logins_total": "mean",
    "active_users": "mean",
    "feature_adoption_score": "mean"
}).reset_index()

# Aggregate tickets
tickets_agg = tickets.groupby("contract_id").agg({
    "ticket_count": "mean",
    "avg_resolution_hours": "mean",
    "csat_score": "mean"
}).reset_index()

# Merge everything
df = contracts.merge(usage_agg, on="contract_id") \
              .merge(tickets_agg, on="contract_id") \
              .merge(renewals, on="contract_id")

# %%
df.info()
df.describe()
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 26 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   contract_id             5000 non-null   int64
#  1   company_id              5000 non-null   int64
#  2   company_size            5000 non-null   int64
#  3   industry                5000 non-null   object
#  4   region                  3139 non-null   object
#  5   growth_rate             5000 non-null   float64
#  6   annual_revenue          5000 non-null   float64
#  7   sales_process_maturity  5000 non-null   float64
#  8   crm_maturity_score      5000 non-null   float64
#  9   seats_start_x           5000 non-null   int64
#  10  plan_tier               5000 non-null   object
#  11  price_per_seat          5000 non-null   int64
#  12  discount_pct            5000 non-null   float64
#  13  contract_value          5000 non-null   float64
#  14  duration_months         5000 non-null   int64
#  15  logins_total_x          5000 non-null   float64
#  16  active_users_x          5000 non-null   float64
#  17  feature_adoption_score  5000 non-null   float64
#  18  ticket_count            5000 non-null   float64
#  19  avg_resolution_hours    5000 non-null   float64
#  20  csat_score              4992 non-null   float64
#  21  seats_start_y           5000 non-null   int64
#  22  logins_total_y          5000 non-null   float64
#  23  active_users_y          5000 non-null   float64
#  24  renewed                 5000 non-null   int64
#  25  seat_change             5000 non-null   int64
# dtypes: float64(14), int64(9), object(3)
# memory usage: 1015.8+ KB
# contract_id                  0
# company_id                   0
# company_size                 0
# industry                     0
# region                    1861
# growth_rate                  0
# annual_revenue               0
# sales_process_maturity       0
# crm_maturity_score           0
# seats_start_x                0
# plan_tier                    0
# price_per_seat               0
# discount_pct                 0
# contract_value               0
# duration_months              0
# logins_total_x               0
# active_users_x               0
# feature_adoption_score       0
# ticket_count                 0
# avg_resolution_hours         0
# csat_score                   8
# seats_start_y                0
# logins_total_y               0
# active_users_y               0
# renewed                      0
# seat_change                  0
# dtype: int64

# %%
import matplotlib.pyplot as plt

plt.hist(df["contract_value"], bins=50)
plt.title("Distribution of Contract Value")
plt.show()

# %%
import numpy as np

df.groupby("renewed")["logins_total_x"].mean()
# Out:
# renewed
# 0     54.051176
# 1    150.988663
# Name: logins_total_x, dtype: float64

# %%
df.groupby("renewed")["feature_adoption_score"].mean()
# Out:
# renewed
# 0    0.432916
# 1    0.529705
# Name: feature_adoption_score, dtype: float64

# %%
df.groupby("renewed")["csat_score"].mean()
# Out:
# renewed
# 0    3.530435
# 1    3.465830
# Name: csat_score, dtype: float64

# %%
df.groupby("renewed")["ticket_count"].mean()
# Out:
# renewed
# 0    1.613193
# 1    4.540506
# Name: ticket_count, dtype: float64

# %%
df.groupby("renewed")["seat_change"].mean()
# Out:
# renewed
# 0    2.582358
# 1    5.080129
# Name: seat_change, dtype: float64

# %%
corr = df.select_dtypes(include=np.number).corr()

plt.imshow(corr)
plt.colorbar()
plt.title("Correlation Matrix")
plt.show()
